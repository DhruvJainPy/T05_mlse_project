# %%
import fitz  # PyMuPDF
from pathlib import Path

# %%
# Path to your PDF
PDF_PATH = Path("spiderman_comic.pdf")

# Folder where extracted images will be saved
OUT_DIR = Path("story_pages")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# Your manually identified story pages (1-based indexing)
story_pages = [1,3,4,5,6,7,8,10,11,13,15,16,17,18,19,20,21,22,24,26,27,29,31,32]

# Open the PDF
doc = fitz.open(PDF_PATH)

print(f"PDF has {len(doc)} pages total.")

# Extract each selected page
for p in story_pages:
    if 1 <= p <= len(doc):
        page = doc[p - 1]           # convert to 0-based index
        pix = page.get_pixmap(dpi=200)   # render at good quality
        out_path = OUT_DIR / f"page_{p:02d}.png"
        pix.save(out_path)
        print(f"Saved page {p} → {out_path}")
    else:
        print(f"Page {p} is out of range, skipping.")
# Out:
# PDF has 36 pages total.
# Saved page 1 → story_pages\page_01.png
# Saved page 3 → story_pages\page_03.png
# Saved page 4 → story_pages\page_04.png
# Saved page 5 → story_pages\page_05.png
# Saved page 6 → story_pages\page_06.png
# Saved page 7 → story_pages\page_07.png
# Saved page 8 → story_pages\page_08.png
# Saved page 10 → story_pages\page_10.png
# Saved page 11 → story_pages\page_11.png
# Saved page 13 → story_pages\page_13.png
# Saved page 15 → story_pages\page_15.png
# Saved page 16 → story_pages\page_16.png
# Saved page 17 → story_pages\page_17.png
# Saved page 18 → story_pages\page_18.png
# Saved page 19 → story_pages\page_19.png
# Saved page 20 → story_pages\page_20.png
# Saved page 21 → story_pages\page_21.png
# Saved page 22 → story_pages\page_22.png
# Saved page 24 → story_pages\page_24.png
# Saved page 26 → story_pages\page_26.png
# Saved page 27 → story_pages\page_27.png
# Saved page 29 → story_pages\page_29.png
# Saved page 31 → story_pages\page_31.png
# Saved page 32 → story_pages\page_32.png

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\aayan\anaconda3\lib\site-packages (10.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector
from PIL import Image
from pathlib import Path
import json

# %%
# story_pages = [1,3,4,5,6,7,8,10,11,13,15,16,17,18,19,20,21,22,24,26,27,29,31,32,]

# %%
# !pip install ultralytics
# !pip install opencv-python pillow
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.231-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (3.9.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (2.5.1+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (0.20.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\aayan\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.35.2-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aayan\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.35.2 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.35.2-cp39-abi3-win_amd64.whl.metadata (1.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aayan\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aayan\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aayan\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aayan\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: filelock in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aayan\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\aayan\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aayan\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Downloading ultralytics-8.3.231-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 2.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.2 MB/s eta 0:00:00
# Downloading polars-1.35.2-py3-none-any.whl (783 kB)
#    ---------------------------------------- 0.0/783.6 kB ? eta -:--:--
#    -------------------------- ------------- 524.3/783.6 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 783.6/783.6 kB 2.4 MB/s eta 0:00:00
# Downloading polars_runtime_32-1.35.2-cp39-abi3-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/41.3 MB 2.8 MB/s eta 0:00:15
#    - -------------------------------------- 1.0/41.3 MB 3.0 MB/s eta 0:00:14
#    - -------------------------------------- 1.6/41.3 MB 2.8 MB/s eta 0:00:15
#    -- ------------------------------------- 2.1/41.3 MB 2.9 MB/s eta 0:00:14
#    -- ------------------------------------- 2.9/41.3 MB 2.9 MB/s eta 0:00:14
#    --- ------------------------------------ 3.4/41.3 MB 3.0 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.2/41.3 MB 3.0 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.7/41.3 MB 3.0 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.2/41.3 MB 2.8 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.8/41.3 MB 2.8 MB/s eta 0:00:13
#    ------ --------------------------------- 6.3/41.3 MB 2.9 MB/s eta 0:00:13
#    ------ --------------------------------- 7.1/41.3 MB 2.8 MB/s eta 0:00:13
#    ------- -------------------------------- 7.6/41.3 MB 2.8 MB/s eta 0:00:13
#    ------- -------------------------------- 8.1/41.3 MB 2.8 MB/s eta 0:00:12
#    -------- ------------------------------- 8.7/41.3 MB 2.8 MB/s eta 0:00:12
#    -------- ------------------------------- 9.2/41.3 MB 2.7 MB/s eta 0:00:12
#    --------- ------------------------------ 9.7/41.3 MB 2.7 MB/s eta 0:00:12
#    ---------- ----------------------------- 10.5/41.3 MB 2.8 MB/s eta 0:00:12
#    ---------- ----------------------------- 11.3/41.3 MB 2.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 11.8/41.3 MB 2.8 MB/s eta 0:00:11
#    ------------ --------------------------- 12.6/41.3 MB 2.8 MB/s eta 0:00:11
#    ------------ --------------------------- 13.1/41.3 MB 2.9 MB/s eta 0:00:10
#    ------------- -------------------------- 13.6/41.3 MB 2.8 MB/s eta 0:00:10
#    ------------- -------------------------- 14.2/41.3 MB 2.8 MB/s eta 0:00:10
#    -------------- ------------------------- 14.7/41.3 MB 2.8 MB/s eta 0:00:10
#    -------------- ------------------------- 15.5/41.3 MB 2.8 MB/s eta 0:00:10
#    --------------- ------------------------ 16.3/41.3 MB 2.8 MB/s eta 0:00:09
#    ---------------- ----------------------- 16.8/41.3 MB 2.9 MB/s eta 0:00:09
#    ----------------- ---------------------- 17.8/41.3 MB 2.9 MB/s eta 0:00:09
#    ------------------ --------------------- 18.6/41.3 MB 2.9 MB/s eta 0:00:08
#    ------------------ --------------------- 19.4/41.3 MB 3.0 MB/s eta 0:00:08
#    ------------------- -------------------- 20.2/41.3 MB 3.0 MB/s eta 0:00:08
#    -------------------- ------------------- 21.0/41.3 MB 3.0 MB/s eta 0:00:07
#    --------------------- ------------------ 22.0/41.3 MB 3.1 MB/s eta 0:00:07
#    ---------------------- ----------------- 23.1/41.3 MB 3.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 24.1/41.3 MB 3.2 MB/s eta 0:00:06
#    ------------------------ --------------- 25.2/41.3 MB 3.2 MB/s eta 0:00:05
#    ------------------------- -------------- 26.2/41.3 MB 3.3 MB/s eta 0:00:05
#    -------------------------- ------------- 27.0/41.3 MB 3.3 MB/s eta 0:00:05
#    --------------------------- ------------ 28.0/41.3 MB 3.3 MB/s eta 0:00:04
#    ---------------------------- ----------- 29.1/41.3 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 30.1/41.3 MB 3.4 MB/s eta 0:00:04
#    ------------------------------ --------- 31.2/41.3 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 32.2/41.3 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 33.0/41.3 MB 3.5 MB/s eta 0:00:03
#    -------------------------------- ------- 33.8/41.3 MB 3.5 MB/s eta 0:00:03
#    --------------------------------- ------ 34.6/41.3 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 35.9/41.3 MB 3.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 37.0/41.3 MB 3.6 MB/s eta 0:00:02
#    ------------------------------------ --- 38.0/41.3 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 39.3/41.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  41.2/41.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 41.3/41.3 MB 3.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: polars-runtime-32, polars, ultralytics-thop, ultralytics
# Successfully installed polars-1.35.2 polars-runtime-32-1.35.2 ultralytics-8.3.231 ultralytics-thop-2.0.18
# Requirement already satisfied: opencv-python in c:\users\aayan\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: pillow in c:\users\aayan\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\aayan\anaconda3\lib\site-packages (from opencv-python) (1.26.4)

# %%
from ultralytics import YOLO
import cv2
from PIL import Image
from pathlib import Path
import json

# -----------------------------
# 1. Paths + Setup
# -----------------------------
MODEL_PATH = "best.pt"         # your fine-tuned panel detector
PAGES_DIR  = Path("story_pages")   # story pages extracted earlier
PANELS_DIR = Path("panels")
PANELS_DIR.mkdir(exist_ok=True)

# -----------------------------
# 2. Load the YOLO model
# -----------------------------
model = YOLO(MODEL_PATH)

# -----------------------------
# 3. Function to detect panels
# -----------------------------
def extract_panels_from_page(page_path):
    img = cv2.imread(str(page_path))

    # Run prediction
    results = model.predict(source=page_path, verbose=False)[0]

    page_id = int(page_path.stem.split("_")[1])
    page_panels = []

    # Loop through detected boxes
    for i, box in enumerate(results.boxes):
        x1, y1, x2, y2 = box.xyxy[0].tolist()
        x1, y1, x2, y2 = map(int, [x1, y1, x2, y2])

        # Crop the panel
        crop = img[y1:y2, x1:x2]

        # Panel ID & save path
        panel_id = f"p{page_id:02d}_{i+1:02d}"
        save_path = PANELS_DIR / f"{panel_id}.png"
        cv2.imwrite(str(save_path), crop)

        # Record metadata
        page_panels.append({
            "page_id": page_id,
            "panel_id": panel_id,
            "image_path": str(save_path),
            "bbox": [x1, y1, x2, y2],
            "confidence": float(box.conf)
        })

    return page_panels

# -----------------------------
# 4. Process all story pages
# -----------------------------
all_panels = []
for page in sorted(PAGES_DIR.glob("*.png")):
    panels = extract_panels_from_page(page)
    print(f"{page.name} → {len(panels)} panels detected")
    all_panels.extend(panels)

# -----------------------------
# 5. Save metadata
# -----------------------------
meta_path = "/mnt/data/panel_metadata_basic.json"
with open(meta_path, "w") as f:
    json.dump(all_panels, f, indent=2)

print(f"\nSaved metadata for {len(all_panels)} panels → {meta_path}")

# %%
from pathlib import Path
import re
import json

PANELS_DIR   = Path("panels")   # change to "panels_auto" if that’s your folder
OUT_META_PATH = Path("panel_metadata.json")

records = []

for img_file in sorted(PANELS_DIR.glob("p*.png")):
    # Expect names like p04_01.png
    m = re.match(r"p(\d{2})_(\d{2})\.png", img_file.name)
    if not m:
        print("Skipping unexpected file name:", img_file.name)
        continue

    page_id = int(m.group(1))          # 4 from p04_01
    panel_idx = int(m.group(2)) - 1    # make 0-based

    records.append({
        "panel_id": img_file.stem,             # "p04_01"
        "page_id": page_id,
        "panel_index": panel_idx,
        "image_path": str(img_file),

        # bbox / confidence unknown here (can be added later if you have them)
        "bbox": None,
        "confidence": None,

        # Text fields to be filled/updated
        "short_caption": "",
        "speech_text": "",
        "story_context": "",
        "characters_in_panel": [],

        # global story position
        "order_index": None
    })

# Sort in reading order
records.sort(key=lambda r: (r["page_id"], r["panel_index"]))

# Assign global order_index
for i, rec in enumerate(records):
    rec["order_index"] = i

with OUT_META_PATH.open("w", encoding="utf-8") as f:
    json.dump(records, f, indent=2, ensure_ascii=False)

print(f"Saved {len(records)} panels → {OUT_META_PATH}")
# Out:
# Skipping unexpected file name: p05_04png.png
# Saved 83 panels → panel_metadata.json

# %%
# !pip install open_clip_torch faiss-cpu pillow tqdm
# Out:
# Collecting open_clip_torch
#   Downloading open_clip_torch-3.2.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: faiss-cpu in c:\users\aayan\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: pillow in c:\users\aayan\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: tqdm in c:\users\aayan\anaconda3\lib\site-packages (4.66.5)
# Requirement already satisfied: torch>=2.0 in c:\users\aayan\anaconda3\lib\site-packages (from open_clip_torch) (2.5.1+cu118)
# Requirement already satisfied: torchvision in c:\users\aayan\anaconda3\lib\site-packages (from open_clip_torch) (0.20.1)
# Requirement already satisfied: regex in c:\users\aayan\anaconda3\lib\site-packages (from open_clip_torch) (2024.11.6)
# Collecting ftfy (from open_clip_torch)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface-hub in c:\users\aayan\anaconda3\lib\site-packages (from open_clip_torch) (0.31.2)
# Requirement already satisfied: safetensors in c:\users\aayan\anaconda3\lib\site-packages (from open_clip_torch) (0.5.3)
# Collecting timm>=1.0.17 (from open_clip_torch)
#   Downloading timm-1.0.22-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\aayan\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\aayan\anaconda3\lib\site-packages (from faiss-cpu) (24.1)
# Requirement already satisfied: colorama in c:\users\aayan\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: pyyaml in c:\users\aayan\anaconda3\lib\site-packages (from timm>=1.0.17->open_clip_torch) (6.0.1)
# Requirement already satisfied: filelock in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (4.13.2)
# Requirement already satisfied: networkx in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aayan\anaconda3\lib\site-packages (from torch>=2.0->open_clip_torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aayan\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=2.0->open_clip_torch) (1.3.0)
# Requirement already satisfied: wcwidth in c:\users\aayan\anaconda3\lib\site-packages (from ftfy->open_clip_torch) (0.2.5)
# Requirement already satisfied: requests in c:\users\aayan\anaconda3\lib\site-packages (from huggingface-hub->open_clip_torch) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aayan\anaconda3\lib\site-packages (from jinja2->torch>=2.0->open_clip_torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aayan\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aayan\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aayan\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aayan\anaconda3\lib\site-packages (from requests->huggingface-hub->open_clip_torch) (2025.6.15)
# Downloading open_clip_torch-3.2.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 2.1 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 2.0 MB/s eta 0:00:00
# Downloading timm-1.0.22-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 2.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.5 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 2.1 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
# Installing collected packages: ftfy, timm, open_clip_torch
#   Attempting uninstall: timm
#     Found existing installation: timm 1.0.15
#     Uninstalling timm-1.0.15:
#       Successfully uninstalled timm-1.0.15
# Successfully installed ftfy-6.3.1 open_clip_torch-3.2.0 timm-1.0.22

# %%
# import json
# from pathlib import Path

# import torch
# from PIL import Image
# import numpy as np
# import open_clip
# from tqdm import tqdm

# # ---- 1. Load CLIP model ----
# model_name = "ViT-B-32"
# pretrained = "openai"

# model, _, preprocess = open_clip.create_model_and_transforms(
#     model_name, 
#     pretrained=pretrained
# )
# tokenizer = open_clip.get_tokenizer(model_name)

# device = "cuda" if torch.cuda.is_available() else "cpu"
# model = model.to(device)
# model.eval()

# # ---- 2. Load your enriched panel metadata ----
# META_PATH = Path("panel_metadata.json")  # change if needed

# with META_PATH.open("r", encoding="utf-8") as f:
#     panels = json.load(f)

# print("Loaded", len(panels), "panels")
# Out:
# open_clip_model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]

# %%
import json

# %%
with open("updated_metadata.json", "r") as f:
    meta = json.load(f)

# %%
meta
# Out:
# [{'panel_id': 'p01_01',
#   'short_caption': 'Spider-Man is ambushed by multiple illusions of Mysterio in a chaotic office scene, with papers and objects flying everywhere.',
#   'speech_text': 'Is this one of Mysterio’s illusions— or am I seeing two of him?',
#   'story_context': "This is the cover of the issue and sets up the central conflict: Mysterio has returned and is using elaborate illusions to confuse and overwhelm Spider-Man. The scene hints that Spider-Man will be forced to confront not just physical threats but deceptive tricks. The chaotic environment reinforces that Mysterio’s illusions disrupt Spider-Man's senses and surroundings.",
#   'characters_in_panel': ['Spider-Man', 'Mysterio'],
#   'text': "[speech_text] : Is this one of Mysterio’s illusions— or am I seeing two of him? And [short_caption] : Spider-Man is ambushed by multiple illusions of Mysterio in a chaotic office scene, with papers and objects flying everywhere. And [story_context] : This is the cover of the issue and sets up the central conflict: Mysterio has returned and is using elaborate illusions to confuse and overwhelm Spider-Man. The scene hints that Spider-Man will be forced to confront not just physical threats but deceptive tricks. The chaotic environment reinforces that Mysterio’s illusions disrupt Spider-Man's senses and surroundings.",
#   'answer': "[speech_text] : Is this one of Mysterio’s illusions— or am I seeing two of him? And [short_caption] : Spider-Man is ambushed by multiple illusions of Mysterio in a chaotic office scene, with papers and objects flying everywhere. And [story_context] : This is the cover of the issue and sets up the central conflict: Mysterio has returned and is using elaborate illusions to confuse and overwhelm Spider-Man. The scene hints that Spider-Man will be forced to confront not just physical threats but deceptive tricks. The chaotic environment reinforces that Mysterio’s illusions disrupt Spider-Man's senses and surroundings.",
#   'image_path': 'panels/p01_01.png'},
#  {'panel_id': 'p01_02',
#   'short_caption': 'Mysterio stands in a darkened interior, surrounded by swirling smoke and papers drifting through the air.',
#   'speech_text': '',
#   'story_context': "This panel highlights Mysterio's presence and reinforces his control over illusions and theatrical effects. The dark room and drifting papers suggest he is manipulating the environment from behind the scenes. This foreshadows his intention to target Spider-Man using deception rather than direct confrontation.",
#   'characters_in_panel': ['Mysterio'],
#   'text': "[short_caption] : Mysterio stands in a darkened interior, surrounded by swirling smoke and papers drifting through the air. And [story_context] : This panel highlights Mysterio's presence and reinforces his control over illusions and theatrical effects. The dark room and drifting papers suggest he is manipulating the environment from behind the scenes. This foreshadows his intention to target Spider-Man using deception rather than direct confrontation.",
#   'answer': "[short_caption] : Mysterio stands in a darkened interior, surrounded by swirling smoke and papers drifting through the air. And [story_context] : This panel highlights Mysterio's presence and reinforces his control over illusions and theatrical effects. The dark room and drifting papers suggest he is manipulating the environment from behind the scenes. This foreshadows his intention to target Spider-Man using deception rather than direct confrontation.",
#   'image_path': 'panels/p01_02.png'},
#  {'panel_id': 'p04_01',
#   'short_caption': 'Spider-Man swings high above the city at dusk, passing over apartments while people notice him from below.',
#   'speech_text': "Well, at least I ended that threat by ditching those other-worldly threads! No one's liable to miss them.",
#   'story_context': 'Spider-Man is returning to routine patrol after resolving a prior conflict involving a mysterious alternate costume. The city atmosphere is calm, and citizens react with excitement as they spot him overhead. This panel sets a light, playful tone before the story transitions into the main conflict with Mysterio.',
#   'characters_in_panel': ['Spider-Man', 'Civilians'],
#   'text': "[speech_text] : Well, at least I ended that threat by ditching those other-worldly threads! No one's liable to miss them. And [short_caption] : Spider-Man swings high above the city at dusk, passing over apartments while people notice him from below. And [story_context] : Spider-Man is returning to routine patrol after resolving a prior conflict involving a mysterious alternate costume. The city atmosphere is calm, and citizens react with excitement as they spot him overhead. This panel sets a light, playful tone before the story transitions into the main conflict with Mysterio.",
#   'answer': "[speech_text] : Well, at least I ended that threat by ditching those other-worldly threads! No one's liable to miss them. And [short_caption] : Spider-Man swings high above the city at dusk, passing over apartments while people notice him from below. And [story_context] : Spider-Man is returning to routine patrol after resolving a prior conflict involving a mysterious alternate costume. The city atmosphere is calm, and citizens react with excitement as they spot him overhead. This panel sets a light, playful tone before the story transitions into the main conflict with Mysterio.",
#   'image_path': 'panels/p04_01.png'},
#  {'panel_id': 'p04_02',
#   'short_caption': 'A group of kids on the street talk excitedly as Spider-Man swings past them.',
#   'speech_text': 'Hey, man, what happened to your black costume? It was a snap! — Yeah, this old one is a drag! Y’oughta burn it! — C’mon, Eddie, you gonna hold onto that spaldeen all night? — Sheesh! Everybody’s a critic!',
#   'story_context': "Spider-Man is teased by kids who preferred his black costume, referencing the transition period when Spidey switched between suits. The dialogue reflects the lighthearted humor and Spider-Man’s playful relationship with New York residents. This continues the calm before the story's tension rises.",
#   'characters_in_panel': ['Spider-Man', 'Civilians', 'Eddie'],
#   'text': "[speech_text] : Hey, man, what happened to your black costume? It was a snap! — Yeah, this old one is a drag! Y’oughta burn it! — C’mon, Eddie, you gonna hold onto that spaldeen all night? — Sheesh! Everybody’s a critic! And [short_caption] : A group of kids on the street talk excitedly as Spider-Man swings past them. And [story_context] : Spider-Man is teased by kids who preferred his black costume, referencing the transition period when Spidey switched between suits. The dialogue reflects the lighthearted humor and Spider-Man’s playful relationship with New York residents. This continues the calm before the story's tension rises.",
#   'answer': "[speech_text] : Hey, man, what happened to your black costume? It was a snap! — Yeah, this old one is a drag! Y’oughta burn it! — C’mon, Eddie, you gonna hold onto that spaldeen all night? — Sheesh! Everybody’s a critic! And [short_caption] : A group of kids on the street talk excitedly as Spider-Man swings past them. And [story_context] : Spider-Man is teased by kids who preferred his black costume, referencing the transition period when Spidey switched between suits. The dialogue reflects the lighthearted humor and Spider-Man’s playful relationship with New York residents. This continues the calm before the story's tension rises.",
#   'image_path': 'panels/p04_02.png'},
#  {'panel_id': 'p04_03',
#   'short_caption': "Spider-Man swings past a large billboard advertising 'Indiana Jones and the Temple of Doom.'",
#   'speech_text': "Hey, there's an ad for that new Indy Jones flick! Maybe that's what I need—some nice, normal relaxation in a nice air-conditioned movie theater! — I've heard nothing but good things about that flick! And it's supposed to have great special effects!",
#   'story_context': 'Spider-Man reflects on needing a break and considers seeing a movie, joking about special effects—an ironic setup given that Mysterio, a master of illusions and effects, is about to re-enter the story. This panel subtly foreshadows the thematic link between Hollywood-style illusions and Mysterio’s tricks.',
#   'characters_in_panel': ['Spider-Man'],
#   'text': "[speech_text] : Hey, there's an ad for that new Indy Jones flick! Maybe that's what I need—some nice, normal relaxation in a nice air-conditioned movie theater! — I've heard nothing but good things about that flick! And it's supposed to have great special effects! And [short_caption] : Spider-Man swings past a large billboard advertising 'Indiana Jones and the Temple of Doom.' And [story_context] : Spider-Man reflects on needing a break and considers seeing a movie, joking about special effects—an ironic setup given that Mysterio, a master of illusions and effects, is about to re-enter the story. This panel subtly foreshadows the thematic link between Hollywood-style illusions and Mysterio’s tricks.",
#   'answer': "[speech_text] : Hey, there's an ad for that new Indy Jones flick! Maybe that's what I need—some nice, normal relaxation in a nice air-conditioned movie theater! — I've heard nothing but good things about that flick! And it's supposed to have great special effects! And [short_caption] : Spider-Man swings past a large billboard advertising 'Indiana Jones and the Temple of Doom.' And [story_context] : Spider-Man reflects on needing a break and considers seeing a movie, joking about special effects—an ironic setup given that Mysterio, a master of illusions and effects, is about to re-enter the story. This panel subtly foreshadows the thematic link between Hollywood-style illusions and Mysterio’s tricks.",
#   'image_path': 'panels/p04_03.png'},
#  {'panel_id': 'p05_01',
#   'short_caption': 'A fortified prison stands in a remote, wooded area, with guards stationed in watchtowers.',
#   'speech_text': "Meanwhile, somewhere upstate— Special effects! That's the answer!",
#   'story_context': "The scene transitions away from Spider-Man to a prison facility, signaling that a villain is plotting from behind bars. The mention of 'special effects' reveals that Mysterio is already scheming, tying back to Spider-Man’s earlier thoughts about movies and illusions.",
#   'characters_in_panel': ['Mysterio (voice/thought)'],
#   'text': "[speech_text] : Meanwhile, somewhere upstate— Special effects! That's the answer! And [short_caption] : A fortified prison stands in a remote, wooded area, with guards stationed in watchtowers. And [story_context] : The scene transitions away from Spider-Man to a prison facility, signaling that a villain is plotting from behind bars. The mention of 'special effects' reveals that Mysterio is already scheming, tying back to Spider-Man’s earlier thoughts about movies and illusions.",
#   'answer': "[speech_text] : Meanwhile, somewhere upstate— Special effects! That's the answer! And [short_caption] : A fortified prison stands in a remote, wooded area, with guards stationed in watchtowers. And [story_context] : The scene transitions away from Spider-Man to a prison facility, signaling that a villain is plotting from behind bars. The mention of 'special effects' reveals that Mysterio is already scheming, tying back to Spider-Man’s earlier thoughts about movies and illusions.",
#   'image_path': 'panels/p05_01.png'},
#  {'panel_id': 'p05_02',
#   'short_caption': 'Mysterio grips the prison bars angrily, glaring out with determination.',
#   'speech_text': 'Very soon now I’ll make use of my skills at creating special effects and escape from this accursed prison! Then Spider-Man will pay for having put me here— pay with his very life!',
#   'story_context': 'This panel reveals that Mysterio is imprisoned but planning an escape using his expertise with illusions and special effects. His vow to take revenge on Spider-Man establishes him as the main antagonist for this issue and builds the stakes for the coming conflict.',
#   'characters_in_panel': ['Mysterio'],
#   'text': '[speech_text] : Very soon now I’ll make use of my skills at creating special effects and escape from this accursed prison! Then Spider-Man will pay for having put me here— pay with his very life! And [short_caption] : Mysterio grips the prison bars angrily, glaring out with determination. And [story_context] : This panel reveals that Mysterio is imprisoned but planning an escape using his expertise with illusions and special effects. His vow to take revenge on Spider-Man establishes him as the main antagonist for this issue and builds the stakes for the coming conflict.',
#   'answer': '[speech_text] : Very soon now I’ll make use of my skills at creating special effects and escape from this accursed prison! Then Spider-Man will pay for having put me here— pay with his very life! And [short_caption] : Mysterio grips the prison bars angrily, glaring out with determination. And [story_context] : This panel reveals that Mysterio is imprisoned but planning an escape using his expertise with illusions and special effects. His vow to take revenge on Spider-Man establishes him as the main antagonist for this issue and builds the stakes for the coming conflict.',
#   'image_path': 'panels/p05_02.png'},
#  {'panel_id': 'p05_03',
#   'short_caption': 'A cosmic setting shows distant planets and a mysterious technological structure rising from an alien landscape.',
#   'speech_text': 'While still another— In a quadrant of the universe countless light years from our Earth— A meeting is being held in this noble Intergalactic Structure! A meeting which may decide the fate of civilized planets everywhere!',
#   'story_context': 'The story shifts to a distant intergalactic setting, introducing an alien council preparing to discuss a threat that spans galaxies. This suggests a parallel plotline involving cosmic stakes beyond Spider-Man’s earthly conflict with Mysterio. It hints that the issue will merge Earth-level events with wider cosmic forces.',
#   'characters_in_panel': ['Alien Council'],
#   'text': '[speech_text] : While still another— In a quadrant of the universe countless light years from our Earth— A meeting is being held in this noble Intergalactic Structure! A meeting which may decide the fate of civilized planets everywhere! And [short_caption] : A cosmic setting shows distant planets and a mysterious technological structure rising from an alien landscape. And [story_context] : The story shifts to a distant intergalactic setting, introducing an alien council preparing to discuss a threat that spans galaxies. This suggests a parallel plotline involving cosmic stakes beyond Spider-Man’s earthly conflict with Mysterio. It hints that the issue will merge Earth-level events with wider cosmic forces.',
#   'answer': '[speech_text] : While still another— In a quadrant of the universe countless light years from our Earth— A meeting is being held in this noble Intergalactic Structure! A meeting which may decide the fate of civilized planets everywhere! And [short_caption] : A cosmic setting shows distant planets and a mysterious technological structure rising from an alien landscape. And [story_context] : The story shifts to a distant intergalactic setting, introducing an alien council preparing to discuss a threat that spans galaxies. This suggests a parallel plotline involving cosmic stakes beyond Spider-Man’s earthly conflict with Mysterio. It hints that the issue will merge Earth-level events with wider cosmic forces.',
#   'image_path': 'panels/p05_03.png'},
#  {'panel_id': 'p05_04',
#   'short_caption': 'A group of robed alien council members gather around a large viewing screen showing a hostile fleet.',
#   'speech_text': 'No! Our worst fears are confirmed! The Black Fleet is unleashing yet another attack—this one on one of our peaceful colonies! What can they be seeking? Total destruction? Conquest? Their only goal!',
#   'story_context': 'The alien council reacts with alarm as a dangerous fleet threatens another peaceful colony. This expands on the cosmic subplot and indicates that an aggressive outside force is destabilizing multiple planets. The council debates their options, setting up a coming crisis that may eventually tie back to Earth.',
#   'characters_in_panel': ['Alien Council'],
#   'text': '[speech_text] : No! Our worst fears are confirmed! The Black Fleet is unleashing yet another attack—this one on one of our peaceful colonies! What can they be seeking? Total destruction? Conquest? Their only goal! And [short_caption] : A group of robed alien council members gather around a large viewing screen showing a hostile fleet. And [story_context] : The alien council reacts with alarm as a dangerous fleet threatens another peaceful colony. This expands on the cosmic subplot and indicates that an aggressive outside force is destabilizing multiple planets. The council debates their options, setting up a coming crisis that may eventually tie back to Earth.',
#   'answer': '[speech_text] : No! Our worst fears are confirmed! The Black Fleet is unleashing yet another attack—this one on one of our peaceful colonies! What can they be seeking? Total destruction? Conquest? Their only goal! And [short_caption] : A group of robed alien council members gather around a large viewing screen showing a hostile fleet. And [story_context] : The alien council reacts with alarm as a dangerous fleet threatens another peaceful colony. This expands on the cosmic subplot and indicates that an aggressive outside force is destabilizing multiple planets. The council debates their options, setting up a coming crisis that may eventually tie back to Earth.',
#   'image_path': 'panels/p05_04.png'},
#  {'panel_id': 'p06_01',
#   'short_caption': 'Alien leaders stand on elevated platforms, addressing a projected starfield filled with warships.',
#   'speech_text': 'No matter what the consequences, we must not relearn the barbaric ways of battle! Better that we should die than suffer such heresy! — Of course you are right, Aged Obispo!',
#   'story_context': 'The council continues debating how to respond to the Black Fleet’s escalating attacks. One leader argues strongly that they cannot resort to violence, emphasizing pacifism and tradition. However, the mounting threat forces them to confront the limits of this philosophy, creating tension within the group.',
#   'characters_in_panel': ['Alien Council', 'Aged Obispo'],
#   'text': '[speech_text] : No matter what the consequences, we must not relearn the barbaric ways of battle! Better that we should die than suffer such heresy! — Of course you are right, Aged Obispo! And [short_caption] : Alien leaders stand on elevated platforms, addressing a projected starfield filled with warships. And [story_context] : The council continues debating how to respond to the Black Fleet’s escalating attacks. One leader argues strongly that they cannot resort to violence, emphasizing pacifism and tradition. However, the mounting threat forces them to confront the limits of this philosophy, creating tension within the group.',
#   'answer': '[speech_text] : No matter what the consequences, we must not relearn the barbaric ways of battle! Better that we should die than suffer such heresy! — Of course you are right, Aged Obispo! And [short_caption] : Alien leaders stand on elevated platforms, addressing a projected starfield filled with warships. And [story_context] : The council continues debating how to respond to the Black Fleet’s escalating attacks. One leader argues strongly that they cannot resort to violence, emphasizing pacifism and tradition. However, the mounting threat forces them to confront the limits of this philosophy, creating tension within the group.',
#   'image_path': 'panels/p06_01.png'},
#  {'panel_id': 'p06_02',
#   'short_caption': 'An elder alien philosopher, Durcan, addresses the council while displaying a captured transmission on a floating monitor.',
#   'speech_text': 'Aye! Only one among us dared suggest that resistance was the nobler course—the philosopher, Durcan! Indeed, our monitors captured his very words and actions. Pay heed to your visi-screens, and learn how low a man may sink!',
#   'story_context': 'The council leader recounts how Durcan previously challenged their pacifist traditions during an earlier crisis. The monitor shows archived footage of Durcan’s defiance. This panel highlights the ideological conflict between tradition and survival that divides the council as they face the growing threat of the Black Fleet.',
#   'characters_in_panel': ['Durcan', 'Alien Council'],
#   'text': '[speech_text] : Aye! Only one among us dared suggest that resistance was the nobler course—the philosopher, Durcan! Indeed, our monitors captured his very words and actions. Pay heed to your visi-screens, and learn how low a man may sink! And [short_caption] : An elder alien philosopher, Durcan, addresses the council while displaying a captured transmission on a floating monitor. And [story_context] : The council leader recounts how Durcan previously challenged their pacifist traditions during an earlier crisis. The monitor shows archived footage of Durcan’s defiance. This panel highlights the ideological conflict between tradition and survival that divides the council as they face the growing threat of the Black Fleet.',
#   'answer': '[speech_text] : Aye! Only one among us dared suggest that resistance was the nobler course—the philosopher, Durcan! Indeed, our monitors captured his very words and actions. Pay heed to your visi-screens, and learn how low a man may sink! And [short_caption] : An elder alien philosopher, Durcan, addresses the council while displaying a captured transmission on a floating monitor. And [story_context] : The council leader recounts how Durcan previously challenged their pacifist traditions during an earlier crisis. The monitor shows archived footage of Durcan’s defiance. This panel highlights the ideological conflict between tradition and survival that divides the council as they face the growing threat of the Black Fleet.',
#   'image_path': 'panels/p06_02.png'},
#  {'panel_id': 'p06_03',
#   'short_caption': 'A council member angrily points from a large monitor where Durcan appears, speaking defiantly.',
#   'speech_text': 'You call me heretic if you will. But I say to you—',
#   'story_context': "Durcan appears onscreen addressing the council members with unwavering conviction. His appearance and tone mark him as an outcast who challenged the council's pacifism in a moment of crisis. His words set the stage for the moral debate that continues to shape their decisions and fears.",
#   'characters_in_panel': ['Durcan', 'Alien Council'],
#   'text': "[speech_text] : You call me heretic if you will. But I say to you— And [short_caption] : A council member angrily points from a large monitor where Durcan appears, speaking defiantly. And [story_context] : Durcan appears onscreen addressing the council members with unwavering conviction. His appearance and tone mark him as an outcast who challenged the council's pacifism in a moment of crisis. His words set the stage for the moral debate that continues to shape their decisions and fears.",
#   'answer': "[speech_text] : You call me heretic if you will. But I say to you— And [short_caption] : A council member angrily points from a large monitor where Durcan appears, speaking defiantly. And [story_context] : Durcan appears onscreen addressing the council members with unwavering conviction. His appearance and tone mark him as an outcast who challenged the council's pacifism in a moment of crisis. His words set the stage for the moral debate that continues to shape their decisions and fears.",
#   'image_path': 'panels/p06_03.png'},
#  {'panel_id': 'p06_04',
#   'short_caption': 'Durcan continues speaking passionately through the monitor, his face intense and resolute.',
#   'speech_text': '—that though our history and our morality militates against our fighting back, it is a greater sin to die without resisting!',
#   'story_context': 'Durcan argues that survival may require abandoning strict pacifist principles. His speech challenges long-standing beliefs and suggests that moral rigidity may lead to their destruction. This deepens the internal conflict within the alien society as they struggle to define the right path.',
#   'characters_in_panel': ['Durcan'],
#   'text': '[speech_text] : —that though our history and our morality militates against our fighting back, it is a greater sin to die without resisting! And [short_caption] : Durcan continues speaking passionately through the monitor, his face intense and resolute. And [story_context] : Durcan argues that survival may require abandoning strict pacifist principles. His speech challenges long-standing beliefs and suggests that moral rigidity may lead to their destruction. This deepens the internal conflict within the alien society as they struggle to define the right path.',
#   'answer': '[speech_text] : —that though our history and our morality militates against our fighting back, it is a greater sin to die without resisting! And [short_caption] : Durcan continues speaking passionately through the monitor, his face intense and resolute. And [story_context] : Durcan argues that survival may require abandoning strict pacifist principles. His speech challenges long-standing beliefs and suggests that moral rigidity may lead to their destruction. This deepens the internal conflict within the alien society as they struggle to define the right path.',
#   'image_path': 'panels/p06_04.png'},
#  {'panel_id': 'p06_05',
#   'short_caption': 'Council members debate fiercely while standing on elevated platforms, gesturing passionately.',
#   'speech_text': 'Durcan is mad! He rejects the basic tenet of our race! — Renounce peace, Durcan, and you become a man without a world! — Continue to cling to peace, Obispo, and we will all be without a world… and our lives!',
#   'story_context': "The council is deeply divided as some denounce Durcan's stance while others support a more defensive approach. Their arguments reflect a society in existential crisis, torn between philosophical ideals and immediate survival. The conflict is escalating, with both sides claiming the moral high ground.",
#   'characters_in_panel': ['Durcan', 'Aged Obispo', 'Alien Council'],
#   'text': "[speech_text] : Durcan is mad! He rejects the basic tenet of our race! — Renounce peace, Durcan, and you become a man without a world! — Continue to cling to peace, Obispo, and we will all be without a world… and our lives! And [short_caption] : Council members debate fiercely while standing on elevated platforms, gesturing passionately. And [story_context] : The council is deeply divided as some denounce Durcan's stance while others support a more defensive approach. Their arguments reflect a society in existential crisis, torn between philosophical ideals and immediate survival. The conflict is escalating, with both sides claiming the moral high ground.",
#   'answer': "[speech_text] : Durcan is mad! He rejects the basic tenet of our race! — Renounce peace, Durcan, and you become a man without a world! — Continue to cling to peace, Obispo, and we will all be without a world… and our lives! And [short_caption] : Council members debate fiercely while standing on elevated platforms, gesturing passionately. And [story_context] : The council is deeply divided as some denounce Durcan's stance while others support a more defensive approach. Their arguments reflect a society in existential crisis, torn between philosophical ideals and immediate survival. The conflict is escalating, with both sides claiming the moral high ground.",
#   'image_path': 'panels/p06_05.png'},
#  {'panel_id': 'p06_06',
#   'short_caption': 'Six council platforms hover in a chamber; one is conspicuously empty as a member speaks solemnly.',
#   'speech_text': 'We bid him be gone from this chamber—and lo! His platform still stands empty— and none among us have seen him since! To where can the heretic have disappeared?',
#   'story_context': 'The council reveals that Durcan disappeared mysteriously after being expelled. His empty platform symbolizes both his absence and the growing uncertainty among the council. His disappearance raises suspicion and foreshadows that he may play a significant role in events unfolding both on his world and beyond.',
#   'characters_in_panel': ['Alien Council', 'Durcan'],
#   'text': '[speech_text] : We bid him be gone from this chamber—and lo! His platform still stands empty— and none among us have seen him since! To where can the heretic have disappeared? And [short_caption] : Six council platforms hover in a chamber; one is conspicuously empty as a member speaks solemnly. And [story_context] : The council reveals that Durcan disappeared mysteriously after being expelled. His empty platform symbolizes both his absence and the growing uncertainty among the council. His disappearance raises suspicion and foreshadows that he may play a significant role in events unfolding both on his world and beyond.',
#   'answer': '[speech_text] : We bid him be gone from this chamber—and lo! His platform still stands empty— and none among us have seen him since! To where can the heretic have disappeared? And [short_caption] : Six council platforms hover in a chamber; one is conspicuously empty as a member speaks solemnly. And [story_context] : The council reveals that Durcan disappeared mysteriously after being expelled. His empty platform symbolizes both his absence and the growing uncertainty among the council. His disappearance raises suspicion and foreshadows that he may play a significant role in events unfolding both on his world and beyond.',
#   'image_path': 'panels/p06_06.png'},
#  {'panel_id': 'p08_01',
#   'short_caption': 'A wide view of the council chamber shows numerous alien leaders preparing for further deliberations.',
#   'speech_text': 'It matters not! We have matters of far greater concern to which we must attend! Let us put our visi-screens away and prepare ourselves to face the inevitable end!',
#   'story_context': 'The council shifts its attention back to the imminent threat to their civilization. Even as internal disagreements persist, they acknowledge that the danger from the Black Fleet demands immediate focus. Their pessimistic tone shows the depth of their fear and the seriousness of the situation.',
#   'characters_in_panel': ['Alien Council'],
#   'text': '[speech_text] : It matters not! We have matters of far greater concern to which we must attend! Let us put our visi-screens away and prepare ourselves to face the inevitable end! And [short_caption] : A wide view of the council chamber shows numerous alien leaders preparing for further deliberations. And [story_context] : The council shifts its attention back to the imminent threat to their civilization. Even as internal disagreements persist, they acknowledge that the danger from the Black Fleet demands immediate focus. Their pessimistic tone shows the depth of their fear and the seriousness of the situation.',
#   'answer': '[speech_text] : It matters not! We have matters of far greater concern to which we must attend! Let us put our visi-screens away and prepare ourselves to face the inevitable end! And [short_caption] : A wide view of the council chamber shows numerous alien leaders preparing for further deliberations. And [story_context] : The council shifts its attention back to the imminent threat to their civilization. Even as internal disagreements persist, they acknowledge that the danger from the Black Fleet demands immediate focus. Their pessimistic tone shows the depth of their fear and the seriousness of the situation.',
#   'image_path': 'panels/p08_01.png'},
#  {'panel_id': 'p08_02',
#   'short_caption': 'A young alien councilor sits pensively, staring at his screen while others discuss grim predictions.',
#   'speech_text': 'But among all those present in the chamber, there is one young philosopher who continues to study his screen… Durcan was my teacher… my friend! I cannot believe he would abandon us, even to save himself! There must be a way to learn where he has gone. And if there is, then I, Tuskar, shall find him!',
#   'story_context': 'Tuskar, a younger council member, refuses to accept that Durcan has deserted their people. His loyalty drives him to seek answers on his own. This panel sets up a subplot in which Tuskar may uncover secrets that the rest of the council is unwilling or afraid to confront.',
#   'characters_in_panel': ['Tuskar', 'Durcan', 'Alien Council'],
#   'text': '[speech_text] : But among all those present in the chamber, there is one young philosopher who continues to study his screen… Durcan was my teacher… my friend! I cannot believe he would abandon us, even to save himself! There must be a way to learn where he has gone. And if there is, then I, Tuskar, shall find him! And [short_caption] : A young alien councilor sits pensively, staring at his screen while others discuss grim predictions. And [story_context] : Tuskar, a younger council member, refuses to accept that Durcan has deserted their people. His loyalty drives him to seek answers on his own. This panel sets up a subplot in which Tuskar may uncover secrets that the rest of the council is unwilling or afraid to confront.',
#   'answer': '[speech_text] : But among all those present in the chamber, there is one young philosopher who continues to study his screen… Durcan was my teacher… my friend! I cannot believe he would abandon us, even to save himself! There must be a way to learn where he has gone. And if there is, then I, Tuskar, shall find him! And [short_caption] : A young alien councilor sits pensively, staring at his screen while others discuss grim predictions. And [story_context] : Tuskar, a younger council member, refuses to accept that Durcan has deserted their people. His loyalty drives him to seek answers on his own. This panel sets up a subplot in which Tuskar may uncover secrets that the rest of the council is unwilling or afraid to confront.',
#   'image_path': 'panels/p08_02.png'},
#  {'panel_id': 'p08_03',
#   'short_caption': 'Tuskar studies his handheld screen, noticing unusual activity in the planetary data banks.',
#   'speech_text': "Perhaps if I patch my visi-screens into the main computer data banks… Hmm, curious. There seems to be some sort of interference… a drain on our planetary computer hook-up! It's nothing major, and with everyone else's attention focused on the threat of the Black Fleet, no one but myself seems to have noticed it!",
#   'story_context': "Tuskar discovers an anomaly in the planet's data systems that no one else has detected. The subtle interference hints at a hidden operation or an external influence. This discovery suggests that Durcan’s disappearance—and possibly the threat to their world—may be tied to something deeper than the council realizes.",
#   'characters_in_panel': ['Tuskar'],
#   'text': "[speech_text] : Perhaps if I patch my visi-screens into the main computer data banks… Hmm, curious. There seems to be some sort of interference… a drain on our planetary computer hook-up! It's nothing major, and with everyone else's attention focused on the threat of the Black Fleet, no one but myself seems to have noticed it! And [short_caption] : Tuskar studies his handheld screen, noticing unusual activity in the planetary data banks. And [story_context] : Tuskar discovers an anomaly in the planet's data systems that no one else has detected. The subtle interference hints at a hidden operation or an external influence. This discovery suggests that Durcan’s disappearance—and possibly the threat to their world—may be tied to something deeper than the council realizes.",
#   'answer': "[speech_text] : Perhaps if I patch my visi-screens into the main computer data banks… Hmm, curious. There seems to be some sort of interference… a drain on our planetary computer hook-up! It's nothing major, and with everyone else's attention focused on the threat of the Black Fleet, no one but myself seems to have noticed it! And [short_caption] : Tuskar studies his handheld screen, noticing unusual activity in the planetary data banks. And [story_context] : Tuskar discovers an anomaly in the planet's data systems that no one else has detected. The subtle interference hints at a hidden operation or an external influence. This discovery suggests that Durcan’s disappearance—and possibly the threat to their world—may be tied to something deeper than the council realizes.",
#   'image_path': 'panels/p08_03.png'},
#  {'panel_id': 'p08_04',
#   'short_caption': 'Tuskar travels across an alien landscape as the setting sun casts a pink glow over distant structures.',
#   'speech_text': "This may bear looking into! I'll begin a check on the source of the drain at once!… While, a short distance away, in an ancient museum that is all but forgotten amid the more modern splendors of the planet—",
#   'story_context': 'Tuskar decides to investigate the strange data drain personally, suspecting it may be connected to Durcan or the Black Fleet. Meanwhile, narration transitions to an abandoned museum, hinting that the truth—and perhaps ancient artifacts—lies there. This setup leads directly into the discovery of crucial relics.',
#   'characters_in_panel': ['Tuskar'],
#   'text': "[speech_text] : This may bear looking into! I'll begin a check on the source of the drain at once!… While, a short distance away, in an ancient museum that is all but forgotten amid the more modern splendors of the planet— And [short_caption] : Tuskar travels across an alien landscape as the setting sun casts a pink glow over distant structures. And [story_context] : Tuskar decides to investigate the strange data drain personally, suspecting it may be connected to Durcan or the Black Fleet. Meanwhile, narration transitions to an abandoned museum, hinting that the truth—and perhaps ancient artifacts—lies there. This setup leads directly into the discovery of crucial relics.",
#   'answer': "[speech_text] : This may bear looking into! I'll begin a check on the source of the drain at once!… While, a short distance away, in an ancient museum that is all but forgotten amid the more modern splendors of the planet— And [short_caption] : Tuskar travels across an alien landscape as the setting sun casts a pink glow over distant structures. And [story_context] : Tuskar decides to investigate the strange data drain personally, suspecting it may be connected to Durcan or the Black Fleet. Meanwhile, narration transitions to an abandoned museum, hinting that the truth—and perhaps ancient artifacts—lies there. This setup leads directly into the discovery of crucial relics.",
#   'image_path': 'panels/p08_04.png'},
#  {'panel_id': 'p08_05',
#   'short_caption': 'Inside the ancient museum, two glowing artifacts—one an energy egg, the other a bio-gem—hover above ornate pedestals.',
#   'speech_text': 'Two unusual objects hover above their ornate pedestals… One is a matter-energy egg… the other… a bio-gem… Each pulses and glows with its own energy wavelengths…',
#   'story_context': 'The museum contains mysterious relics of great power: an energy-based artifact and a bio-gem. Their hovering presence indicates advanced or ancient technology, possibly linked to the interference Tuskar detected. These artifacts foreshadow a larger cosmic connection that may affect both the alien world and Spider-Man’s storyline.',
#   'characters_in_panel': ['Ancient Artifacts'],
#   'text': '[speech_text] : Two unusual objects hover above their ornate pedestals… One is a matter-energy egg… the other… a bio-gem… Each pulses and glows with its own energy wavelengths… And [short_caption] : Inside the ancient museum, two glowing artifacts—one an energy egg, the other a bio-gem—hover above ornate pedestals. And [story_context] : The museum contains mysterious relics of great power: an energy-based artifact and a bio-gem. Their hovering presence indicates advanced or ancient technology, possibly linked to the interference Tuskar detected. These artifacts foreshadow a larger cosmic connection that may affect both the alien world and Spider-Man’s storyline.',
#   'answer': '[speech_text] : Two unusual objects hover above their ornate pedestals… One is a matter-energy egg… the other… a bio-gem… Each pulses and glows with its own energy wavelengths… And [short_caption] : Inside the ancient museum, two glowing artifacts—one an energy egg, the other a bio-gem—hover above ornate pedestals. And [story_context] : The museum contains mysterious relics of great power: an energy-based artifact and a bio-gem. Their hovering presence indicates advanced or ancient technology, possibly linked to the interference Tuskar detected. These artifacts foreshadow a larger cosmic connection that may affect both the alien world and Spider-Man’s storyline.',
#   'image_path': 'panels/p08_05.png'},
#  {'panel_id': 'p08_06',
#   'short_caption': 'The bio-gem glows intensely, causing a radiant pulse that fills the chamber.',
#   'speech_text': 'But when the bio-gem pulses, there is a corresponding glow from the nearby console of an ages-old computer! The gem pulses...',
#   'story_context': 'The bio-gem reacts to some unseen stimulus and begins emitting a powerful energy pulse. This reaction awakens an ancient computer system, hinting at a linkage between the relic and forgotten planetary technology. The mysterious interaction suggests that the gem’s power is far greater than previously understood.',
#   'characters_in_panel': ['Bio-Gem'],
#   'text': '[speech_text] : But when the bio-gem pulses, there is a corresponding glow from the nearby console of an ages-old computer! The gem pulses... And [short_caption] : The bio-gem glows intensely, causing a radiant pulse that fills the chamber. And [story_context] : The bio-gem reacts to some unseen stimulus and begins emitting a powerful energy pulse. This reaction awakens an ancient computer system, hinting at a linkage between the relic and forgotten planetary technology. The mysterious interaction suggests that the gem’s power is far greater than previously understood.',
#   'answer': '[speech_text] : But when the bio-gem pulses, there is a corresponding glow from the nearby console of an ages-old computer! The gem pulses... And [short_caption] : The bio-gem glows intensely, causing a radiant pulse that fills the chamber. And [story_context] : The bio-gem reacts to some unseen stimulus and begins emitting a powerful energy pulse. This reaction awakens an ancient computer system, hinting at a linkage between the relic and forgotten planetary technology. The mysterious interaction suggests that the gem’s power is far greater than previously understood.',
#   'image_path': 'panels/p08_06.png'},
#  {'panel_id': 'p08_07',
#   'short_caption': 'An ancient computer console lights up, its screens glowing with sudden power.',
#   'speech_text': 'The computer glows...',
#   'story_context': 'The ancient computer responds to the activation of the bio-gem, illuminating as though reawakening after centuries of dormancy. This implies that the artifacts within the museum are part of a larger technological network. The awakening machinery foreshadows an imminent revelation about the gem’s role.',
#   'characters_in_panel': ['Ancient Computer'],
#   'text': '[speech_text] : The computer glows... And [short_caption] : An ancient computer console lights up, its screens glowing with sudden power. And [story_context] : The ancient computer responds to the activation of the bio-gem, illuminating as though reawakening after centuries of dormancy. This implies that the artifacts within the museum are part of a larger technological network. The awakening machinery foreshadows an imminent revelation about the gem’s role.',
#   'answer': '[speech_text] : The computer glows... And [short_caption] : An ancient computer console lights up, its screens glowing with sudden power. And [story_context] : The ancient computer responds to the activation of the bio-gem, illuminating as though reawakening after centuries of dormancy. This implies that the artifacts within the museum are part of a larger technological network. The awakening machinery foreshadows an imminent revelation about the gem’s role.',
#   'image_path': 'panels/p08_07.png'},
#  {'panel_id': 'p08_08',
#   'short_caption': 'The bio-gem floats in midair as glowing patterns form around it.',
#   'speech_text': "And a pattern emerges. It becomes clear that the gem is manipulating the computer's functions.",
#   'story_context': 'The gem reveals its true capabilities by actively interfacing with the ancient computer. Its manipulation of the system confirms it possesses intelligence or pre-programmed control features. This panel deepens the mystery around the bio-gem, suggesting it plays a pivotal role in interstellar events.',
#   'characters_in_panel': ['Bio-Gem'],
#   'text': "[speech_text] : And a pattern emerges. It becomes clear that the gem is manipulating the computer's functions. And [short_caption] : The bio-gem floats in midair as glowing patterns form around it. And [story_context] : The gem reveals its true capabilities by actively interfacing with the ancient computer. Its manipulation of the system confirms it possesses intelligence or pre-programmed control features. This panel deepens the mystery around the bio-gem, suggesting it plays a pivotal role in interstellar events.",
#   'answer': "[speech_text] : And a pattern emerges. It becomes clear that the gem is manipulating the computer's functions. And [short_caption] : The bio-gem floats in midair as glowing patterns form around it. And [story_context] : The gem reveals its true capabilities by actively interfacing with the ancient computer. Its manipulation of the system confirms it possesses intelligence or pre-programmed control features. This panel deepens the mystery around the bio-gem, suggesting it plays a pivotal role in interstellar events.",
#   'image_path': 'panels/p08_08.png'},
#  {'panel_id': 'p08_09',
#   'short_caption': 'The ancient computer displays energy fluctuations within its glowing screens.',
#   'speech_text': "This then is the drain on the planet's computer systems! The bio-gem is using the computer to beam transmissions—",
#   'story_context': "Tuskar's earlier discovery is confirmed: the gem is draining planetary resources to broadcast transmissions across vast distances. This act suggests the gem may be summoning someone or signaling a threat. Its power poses both a technological and existential danger to the planet.",
#   'characters_in_panel': ['Bio-Gem', 'Ancient Computer'],
#   'text': "[speech_text] : This then is the drain on the planet's computer systems! The bio-gem is using the computer to beam transmissions— And [short_caption] : The ancient computer displays energy fluctuations within its glowing screens. And [story_context] : Tuskar's earlier discovery is confirmed: the gem is draining planetary resources to broadcast transmissions across vast distances. This act suggests the gem may be summoning someone or signaling a threat. Its power poses both a technological and existential danger to the planet.",
#   'answer': "[speech_text] : This then is the drain on the planet's computer systems! The bio-gem is using the computer to beam transmissions— And [short_caption] : The ancient computer displays energy fluctuations within its glowing screens. And [story_context] : Tuskar's earlier discovery is confirmed: the gem is draining planetary resources to broadcast transmissions across vast distances. This act suggests the gem may be summoning someone or signaling a threat. Its power poses both a technological and existential danger to the planet.",
#   'image_path': 'panels/p08_09.png'},
#  {'panel_id': 'p10_01',
#   'short_caption': 'A massive beam of energy shoots across the starfield toward a cracked and dying planet.',
#   'speech_text': 'The first of these transmissions is arriving on the target planet, traveling through the vastness of intergalactic space.',
# ...
#   'image_path': 'panels/p24_03.png'},
#  {'panel_id': 'p26_01',
#   'file_name': '/mnt/data/p26_01.png',
#   'description': 'Mysterio confronts Spider-Man again, this time physically present, preparing for another fight.',
#   'characters': ['Spider-Man', 'Mysterio'],
#   'objects': [],
#   'location': 'office interior',
#   'text_in_panel': ['WELCOME, SPIDER-MAN! HOW NICE OF YOU TO SAVE ME THE TROUBLE OF TRACKING YOU DOWN AGAIN!',
#    'HOW CAN YOU BE WAITING FOR ME IN THIS ROOM TOO?!',
#    "YOU'RE PROBABLY JUST ANOTHER EMPTY PIECE OF CLOTH!"],
#   'text': "[location] : office interior And [text_in_panel] : WELCOME, SPIDER-MAN! HOW NICE OF YOU TO SAVE ME THE TROUBLE OF TRACKING YOU DOWN AGAIN! HOW CAN YOU BE WAITING FOR ME IN THIS ROOM TOO?! YOU'RE PROBABLY JUST ANOTHER EMPTY PIECE OF CLOTH! And [description] : Mysterio confronts Spider-Man again, this time physically present, preparing for another fight.",
#   'answer': "[location] : office interior And [text_in_panel] : WELCOME, SPIDER-MAN! HOW NICE OF YOU TO SAVE ME THE TROUBLE OF TRACKING YOU DOWN AGAIN! HOW CAN YOU BE WAITING FOR ME IN THIS ROOM TOO?! YOU'RE PROBABLY JUST ANOTHER EMPTY PIECE OF CLOTH! And [description] : Mysterio confronts Spider-Man again, this time physically present, preparing for another fight.",
#   'image_path': 'panels/p26_01.png'},
#  {'panel_id': 'p26_02',
#   'file_name': '/mnt/data/p26_02.png',
#   'description': 'Mysterio attacks Spider-Man with physical blows as Spidey realizes this Mysterio is the real one.',
#   'characters': ['Spider-Man', 'Mysterio'],
#   'objects': ['smoke'],
#   'location': 'office interior',
#   'text_in_panel': ['FOOL! HOW DARE YOU LAY HANDS ON MYSTERIO!',
#    'YOU SEEM TO HAVE TAKEN LEAVE OF YOUR SENSES, SPIDER-MAN!',
#    'A BIT CRUDE, PERHAPS, BUT CERTAINLY THE MOST SATISFYING WAY TO DEFEAT YOU!',
#    'OOF! THIS ONE REALLY IS MYSTERIO!'],
#   'text': '[location] : office interior And [text_in_panel] : FOOL! HOW DARE YOU LAY HANDS ON MYSTERIO! YOU SEEM TO HAVE TAKEN LEAVE OF YOUR SENSES, SPIDER-MAN! A BIT CRUDE, PERHAPS, BUT CERTAINLY THE MOST SATISFYING WAY TO DEFEAT YOU! OOF! THIS ONE REALLY IS MYSTERIO! And [description] : Mysterio attacks Spider-Man with physical blows as Spidey realizes this Mysterio is the real one.',
#   'answer': '[location] : office interior And [text_in_panel] : FOOL! HOW DARE YOU LAY HANDS ON MYSTERIO! YOU SEEM TO HAVE TAKEN LEAVE OF YOUR SENSES, SPIDER-MAN! A BIT CRUDE, PERHAPS, BUT CERTAINLY THE MOST SATISFYING WAY TO DEFEAT YOU! OOF! THIS ONE REALLY IS MYSTERIO! And [description] : Mysterio attacks Spider-Man with physical blows as Spidey realizes this Mysterio is the real one.',
#   'image_path': 'panels/p26_02.png'},
#  {'panel_id': 'p26_03',
#   'page_id': 26,
#   'image_path': 'panels/p26_03.png',
#   'narration': 'Mysterio prepares to destroy Spider-Man with his black hole weapon.',
#   'dialogue': ['NOW, SPIDER-MAN, I HAVE YOU AT MY MERCY!',
#    'I spent long hours preparing for your demise and my black holes shall be the instrument of your destruction!',
#    'But wait—who is THAT?!',
#    "Are you kidding? No, I don't think you are.",
#    "Then this 'Chief Examiner' character ISN’T just another one of your gimmicks!",
#    "Certainly not! But whoever he may be, I'll deal with him just as soon as my black hole projector has destroyed YOU!"],
#   'characters': ['Spider-Man', 'Mysterio', 'Chief Examiner'],
#   'scene_summary': 'Mysterio prepares to eliminate Spider-Man, but is startled by the arrival of the mysterious Chief Examiner.',
#   'story_context_before': 'The Chief Examiner interferes in Mysterio’s battle, revealing he is not one of Mysterio’s illusions.',
#   'story_context_after': 'The Chief Examiner uses a strange portal to force Spider-Man into another dimension.',
#   'text': '[scene_summary] : Mysterio prepares to eliminate Spider-Man, but is startled by the arrival of the mysterious Chief Examiner. And [story_context_before] : The Chief Examiner interferes in Mysterio’s battle, revealing he is not one of Mysterio’s illusions. And [story_context_after] : The Chief Examiner uses a strange portal to force Spider-Man into another dimension.',
#   'answer': '[scene_summary] : Mysterio prepares to eliminate Spider-Man, but is startled by the arrival of the mysterious Chief Examiner. And [story_context_before] : The Chief Examiner interferes in Mysterio’s battle, revealing he is not one of Mysterio’s illusions. And [story_context_after] : The Chief Examiner uses a strange portal to force Spider-Man into another dimension.'},
#  {'panel_id': 'p27_01',
#   'page_id': 27,
#   'image_path': 'panels/p27_01.png',
#   'narration': 'Spider-Man is forced toward the portal.',
#   'dialogue': ['NOW DIE, SPIDER-MAN!',
#    "Uh-oh, cornered! I don't know what this portal thingy is—",
#    "But I've SEEN what Mysty's black holes can do, so I guess I'll take my chances.",
#    'Good! Spider-Man enters the portal of his own volition.',
#    "Gangway, I'm coming..."],
#   'characters': ['Spider-Man', 'Mysterio', 'Chief Examiner'],
#   'scene_summary': 'Spider-Man chooses to jump through the dimensional portal rather than face Mysterio’s black hole weapon.',
#   'story_context_before': 'Spider-Man faces lethal danger from Mysterio’s weapon.',
#   'story_context_after': 'Inside the portal, Spider-Man undergoes a mind-stripping examination.',
#   'text': '[scene_summary] : Spider-Man chooses to jump through the dimensional portal rather than face Mysterio’s black hole weapon. And [story_context_before] : Spider-Man faces lethal danger from Mysterio’s weapon. And [story_context_after] : Inside the portal, Spider-Man undergoes a mind-stripping examination.',
#   'answer': '[scene_summary] : Spider-Man chooses to jump through the dimensional portal rather than face Mysterio’s black hole weapon. And [story_context_before] : Spider-Man faces lethal danger from Mysterio’s weapon. And [story_context_after] : Inside the portal, Spider-Man undergoes a mind-stripping examination.'},
#  {'panel_id': 'p29_01',
#   'page_id': 29,
#   'image_path': 'panels/p29_01.png',
#   'narration': 'Spider-Man’s memories and identity are scanned.',
#   'dialogue': ['Where his being is stripped to its very essence—',
#    'Every thought, every sensation he has ever had is laid bare to the probing portal...'],
#   'characters': ['Spider-Man',
#    'Chief Examiner',
#    'Various villains and allies (hallucinations)'],
#   'scene_summary': 'Inside the dimensional rift, Spider-Man relives past experiences and faces a psychic examination.',
#   'story_context_before': 'Spider-Man enters the portal to escape Mysterio.',
#   'story_context_after': 'The Chief Examiner attempts to absorb Spider-Man’s powers.',
#   'text': '[scene_summary] : Inside the dimensional rift, Spider-Man relives past experiences and faces a psychic examination. And [story_context_before] : Spider-Man enters the portal to escape Mysterio. And [story_context_after] : The Chief Examiner attempts to absorb Spider-Man’s powers.',
#   'answer': '[scene_summary] : Inside the dimensional rift, Spider-Man relives past experiences and faces a psychic examination. And [story_context_before] : Spider-Man enters the portal to escape Mysterio. And [story_context_after] : The Chief Examiner attempts to absorb Spider-Man’s powers.'},
#  {'panel_id': 'p29_02',
#   'page_id': 29,
#   'image_path': 'panels/p29_02.png',
#   'narration': 'Spider-Man’s energy is drained.',
#   'dialogue': ['Then, as the examination ends, Spider-Man feels his power being swiftly drained away!'],
#   'characters': ['Spider-Man', 'Chief Examiner'],
#   'scene_summary': 'The Chief Examiner siphons Spider-Man’s power as part of his mysterious mission.',
#   'story_context_before': 'Spider-Man undergoes the mind-probe in the portal.',
#   'story_context_after': 'Spider-Man emerges weakened and collapsing.',
#   'text': '[scene_summary] : The Chief Examiner siphons Spider-Man’s power as part of his mysterious mission. And [story_context_before] : Spider-Man undergoes the mind-probe in the portal. And [story_context_after] : Spider-Man emerges weakened and collapsing.',
#   'answer': '[scene_summary] : The Chief Examiner siphons Spider-Man’s power as part of his mysterious mission. And [story_context_before] : Spider-Man undergoes the mind-probe in the portal. And [story_context_after] : Spider-Man emerges weakened and collapsing.'},
#  {'panel_id': 'p29_03',
#   'page_id': 29,
#   'image_path': 'panels/p29_03.png',
#   'narration': 'The Chief Examiner celebrates Spider-Man’s defeat.',
#   'dialogue': ['Excellent! The secrets of Spider-Man’s powers are now added to those of the Hulk!',
#    'My mission is a success!'],
#   'characters': ['Chief Examiner'],
#   'scene_summary': 'The Chief Examiner absorbs Spider-Man’s powers and declares his mission complete.',
#   'story_context_before': 'Spider-Man’s essence was scanned in the portal.',
#   'story_context_after': 'Spider-Man collapses as Mysterio prepares to attack again.',
#   'text': '[scene_summary] : The Chief Examiner absorbs Spider-Man’s powers and declares his mission complete. And [story_context_before] : Spider-Man’s essence was scanned in the portal. And [story_context_after] : Spider-Man collapses as Mysterio prepares to attack again.',
#   'answer': '[scene_summary] : The Chief Examiner absorbs Spider-Man’s powers and declares his mission complete. And [story_context_before] : Spider-Man’s essence was scanned in the portal. And [story_context_after] : Spider-Man collapses as Mysterio prepares to attack again.'},
#  {'panel_id': 'p31_01',
#   'page_id': 31,
#   'image_path': 'panels/p31_01.png',
#   'narration': 'Spider-Man emerges weak from the portal.',
#   'dialogue': ['Even as the Chief Examiner revels in his triumph, Spider-Man finishes his brief journey through the portal...',
#    'Ungh! I—I feel so weak! Like I left all my energy behind me in there!'],
#   'characters': ['Spider-Man', 'Chief Examiner', 'Mysterio'],
#   'scene_summary': 'Spider-Man stumbles out of the portal, drained and vulnerable before his enemies.',
#   'story_context_before': 'The Chief Examiner steals Spider-Man’s powers.',
#   'story_context_after': 'Mysterio attempts to finish Spider-Man off.',
#   'text': '[scene_summary] : Spider-Man stumbles out of the portal, drained and vulnerable before his enemies. And [story_context_before] : The Chief Examiner steals Spider-Man’s powers. And [story_context_after] : Mysterio attempts to finish Spider-Man off.',
#   'answer': '[scene_summary] : Spider-Man stumbles out of the portal, drained and vulnerable before his enemies. And [story_context_before] : The Chief Examiner steals Spider-Man’s powers. And [story_context_after] : Mysterio attempts to finish Spider-Man off.'},
#  {'panel_id': 'p31_02',
#   'page_id': 31,
#   'image_path': 'panels/p31_02.png',
#   'narration': 'The Chief Examiner and portal fade away.',
#   'dialogue': ['Indeed? Then I shall dispatch you quickly and turn my attentions to this upstart imposter!',
#    'What’s this?! The Chief Examiner and his accursed portal are disappearing just as I was about to launch a counter-attack!'],
#   'characters': ['Mysterio', 'Chief Examiner'],
#   'scene_summary': 'Mysterio is frustrated as the Chief Examiner vanishes before he can retaliate.',
#   'story_context_before': 'Spider-Man exits the portal weakened.',
#   'story_context_after': 'Mysterio prepares a final confrontation with Spider-Man.',
#   'text': '[scene_summary] : Mysterio is frustrated as the Chief Examiner vanishes before he can retaliate. And [story_context_before] : Spider-Man exits the portal weakened. And [story_context_after] : Mysterio prepares a final confrontation with Spider-Man.',
#   'answer': '[scene_summary] : Mysterio is frustrated as the Chief Examiner vanishes before he can retaliate. And [story_context_before] : Spider-Man exits the portal weakened. And [story_context_after] : Mysterio prepares a final confrontation with Spider-Man.'},
#  {'panel_id': 'p31_03',
#   'page_id': 31,
#   'image_path': 'panels/p31_03.png',
#   'narration': 'Mysterio tries to attack Spider-Man.',
#   'dialogue': ['Good! That leaves me free to deal with Spider-Man once and for all!',
#    'But—He—He’s gone! How’d he move so weak...'],
#   'characters': ['Mysterio'],
#   'scene_summary': 'Mysterio realizes Spider-Man has moved unexpectedly quickly despite being drained.',
#   'story_context_before': 'The Chief Examiner disappears.',
#   'story_context_after': 'Spider-Man ambushes Mysterio.',
#   'text': '[scene_summary] : Mysterio realizes Spider-Man has moved unexpectedly quickly despite being drained. And [story_context_before] : The Chief Examiner disappears. And [story_context_after] : Spider-Man ambushes Mysterio.',
#   'answer': '[scene_summary] : Mysterio realizes Spider-Man has moved unexpectedly quickly despite being drained. And [story_context_before] : The Chief Examiner disappears. And [story_context_after] : Spider-Man ambushes Mysterio.'},
#  {'panel_id': 'p31_04',
#   'page_id': 31,
#   'image_path': 'panels/p31_04.png',
#   'narration': 'Spider-Man attacks from above.',
#   'dialogue': ['THWIP!',
#    'How touching. I had no idea you were so concerned about my well-being, Mysty!',
#    'Don’t worry, I’m feeling stronger every minute!'],
#   'characters': ['Spider-Man', 'Mysterio'],
#   'scene_summary': 'Spider-Man rebounds, regaining strength and disarming Mysterio.',
#   'story_context_before': 'Mysterio searches for weakened Spider-Man.',
#   'story_context_after': 'Spider-Man begins dismantling Mysterio’s gadgets.',
#   'text': '[scene_summary] : Spider-Man rebounds, regaining strength and disarming Mysterio. And [story_context_before] : Mysterio searches for weakened Spider-Man. And [story_context_after] : Spider-Man begins dismantling Mysterio’s gadgets.',
#   'answer': '[scene_summary] : Spider-Man rebounds, regaining strength and disarming Mysterio. And [story_context_before] : Mysterio searches for weakened Spider-Man. And [story_context_after] : Spider-Man begins dismantling Mysterio’s gadgets.'},
#  {'panel_id': 'p31_05',
#   'page_id': 31,
#   'image_path': 'panels/p31_05.png',
#   'narration': 'The final defeat of Mysterio.',
#   'dialogue': ['Okay, all you Bugle employees, it’s safe to come out now!',
#    'Maybe you’d like an exclusive on what the well-dressed super-villain is wearing these days!',
#    'You’ll pay for this humiliation!'],
#   'characters': ['Spider-Man', 'Mysterio'],
#   'scene_summary': 'Spider-Man humiliates and captures Mysterio, ending the crisis at the Daily Bugle.',
#   'story_context_before': 'Spider-Man disarms Mysterio’s gadgets and beats him.',
#   'story_context_after': 'Spider-Man prepares to continue his day, the threat resolved.',
#   'text': '[scene_summary] : Spider-Man humiliates and captures Mysterio, ending the crisis at the Daily Bugle. And [story_context_before] : Spider-Man disarms Mysterio’s gadgets and beats him. And [story_context_after] : Spider-Man prepares to continue his day, the threat resolved.',
#   'answer': '[scene_summary] : Spider-Man humiliates and captures Mysterio, ending the crisis at the Daily Bugle. And [story_context_before] : Spider-Man disarms Mysterio’s gadgets and beats him. And [story_context_after] : Spider-Man prepares to continue his day, the threat resolved.'},
#  {'panel_id': 'p32_01',
#   'page_id': 32,
#   'panel_index': 0,
#   'image_path': 'panels\\p32_01.png',
#   'bbox': None,
#   'confidence': None,
#   'short_caption': '',
#   'speech_text': '',
#   'story_context': '',
#   'characters_in_panel': [],
#   'order_index': 80,
#   'text': '',
#   'answer': ''},
#  {'panel_id': 'p32_02',
#   'page_id': 32,
#   'panel_index': 1,
#   'image_path': 'panels\\p32_02.png',
#   'bbox': None,
#   'confidence': None,
#   'short_caption': '',
#   'speech_text': '',
#   'story_context': '',
#   'characters_in_panel': [],
#   'order_index': 81,
#   'text': '',
#   'answer': ''},
#  {'panel_id': 'p32_03',
#   'page_id': 32,
#   'panel_index': 2,
#   'image_path': 'panels\\p32_03.png',
#   'bbox': None,
#   'confidence': None,
#   'short_caption': '',
#   'speech_text': '',
#   'story_context': '',
#   'characters_in_panel': [],
#   'order_index': 82,
#   'text': '',
#   'answer': ''}]

# %%
# def ensure_image_paths(meta, base_dir="panels"):
#     """
#     Ensures each metadata entry has an 'image_path' key.
#     If missing, it auto-generates one using:
#         f"{base_dir}/{panel_id}.png"
    
#     Args:
#         meta (list[dict]): metadata list loaded from JSON
#         base_dir (str): folder containing panel images
#     Returns:
#         meta (list[dict]): updated metadata list
#     """

#     for entry in meta:
#         panel_id = entry.get("panel_id")  # e.g., "p01_01"
#         if panel_id is None:
#             print("⚠️  Missing panel_id in entry:", entry)
#             continue

#         # Construct the expected image path
#         expected_path = f"{base_dir}/{panel_id}.png"

#         # Add only if missing or empty
#         if "image_path" not in entry or not entry["image_path"]:
#             entry["image_path"] = expected_path

#     return meta

# %%
# Suppose `meta` is already loaded
meta = ensure_image_paths(meta)

# %%
import json

output_path = "updated_metadata.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=4, ensure_ascii=False)

print("Saved JSON to:", output_path)
# Out:
# Saved JSON to: updated_metadata.json

# %%
import torch

# %%
emb = torch.load("panel_clip_embeddings.pt")
panel_ids      = emb["panel_ids"]       # list[str]
image_paths    = emb["image_paths"]     # list[str]
texts          = emb["texts"]           # list[str]
image_features = emb["image_features"]  # torch.Size([N, D])
text_features  = emb["text_features"]   # torch.Size([N, D])

# 2) Load your metadata JSON
  # list of dicts, each has "panel_id"
# Out:
# C:\Users\aayan\AppData\Local\Temp\ipykernel_21760\2836585970.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   emb = torch.load("panel_clip_embeddings.pt")

# %%
print(len(panel_ids), len(image_features), len(meta))
# Out:
# 82 82 83

# %%
import torch.nn.functional as F

image_features_norm = F.normalize(image_features, dim=1)
text_features_norm  = F.normalize(text_features, dim=1)

# %%
import faiss
import numpy as np

# %%
img_mat = image_features_norm.numpy().astype("float32")
text_mat = text_features_norm.numpy().astype("float32")

# %%
d = img_mat.shape[1]
d
# Out:
# 512

# %%
# building the FAISS index
image_index = faiss.IndexFlatIP(d)
image_index.add(img_mat)

text_index = faiss.IndexFlatIP(d)
text_index.add(text_mat)

# %%
import numpy as np

panel_ids   = np.array(emb["panel_ids"])
image_paths = np.array(emb["image_paths"])
texts       = np.array(emb["texts"])   # enriched text field you built

# %%
import torch
from PIL import Image
import clip   # or from open_clip import create_model_and_transforms, etc.

device = "cuda" if torch.cuda.is_available() else "cpu"

# make sure you load the same CLIP model+preprocess you used for the DB
model, preprocess = clip.load("ViT-B/32", device=device)
model.eval()

def search_images_by_text(query, k=5):
    # 1) encode query text with CLIP
    with torch.no_grad():
        tokens = clip.tokenize([query]).to(device)
        q_feat = model.encode_text(tokens)
        q_feat = q_feat / q_feat.norm(dim=-1, keepdim=True)

    # 2) convert to numpy for FAISS
    q_vec = q_feat.cpu().numpy().astype("float32")

    # 3) search in image index
    sims, idxs = image_index.search(q_vec, k)   # (1, k)

    # 4) build pretty results
    results = []
    for rank, (score, idx) in enumerate(zip(sims[0], idxs[0]), start=1):
        pid   = panel_ids[idx]
        ipath = image_paths[idx]
        base  = {
            "rank": rank,
            "score": float(score),
            "panel_id": str(pid),
            "image_path": str(ipath),
            "db_text": str(texts[idx]),
        }
        # attach rich metadata if available
        if pid in panel_meta:
            base["metadata"] = panel_meta[pid]
        results.append(base)

    return results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[81], line 3
#       1 import torch
#       2 from PIL import Image
# ----> 3 import clip   # or from open_clip import create_model_and_transforms, etc.
#       5 device = "cuda" if torch.cuda.is_available() else "cpu"
#       7 # make sure you load the same CLIP model+preprocess you used for the DB
#
# ModuleNotFoundError: No module named 'clip'

# %%
import torch
import clip

device = "cuda" if torch.cuda.is_available() else "cpu"

model, preprocess = clip.load("ViT-B/32", device=device)
model.eval()

print("Loaded model:", type(model))
# Out:
# 100%|███████████████████████████████████████| 338M/338M [00:32<00:00, 11.1MiB/s]
# Loaded model: <class 'clip.model.CLIP'>

# %%
import torch
from PIL import Image
import clip   # or from open_clip import create_model_and_transforms, etc.

device = "cuda" if torch.cuda.is_available() else "cpu"

# make sure you load the same CLIP model+preprocess you used for the DB
model, preprocess = clip.load("ViT-B/32", device=device)
model.eval()

def search_images_by_text(query, k=5):
    # 1) encode query text with CLIP
    with torch.no_grad():
        tokens = clip.tokenize([query]).to(device)
        q_feat = model.encode_text(tokens)
        q_feat = q_feat / q_feat.norm(dim=-1, keepdim=True)

    # 2) convert to numpy for FAISS
    q_vec = q_feat.cpu().numpy().astype("float32")

    # 3) search in image index
    sims, idxs = image_index.search(q_vec, k)   # (1, k)

    # 4) build pretty results
    results = []
    for rank, (score, idx) in enumerate(zip(sims[0], idxs[0]), start=1):
        pid   = panel_ids[idx]
        ipath = image_paths[idx]
        base  = {
            "rank": rank,
            "score": float(score),
            "panel_id": str(pid),
            "image_path": str(ipath),
            "db_text": str(texts[idx]),
        }
        # attach rich metadata if available
        if pid in panel_meta:
            base["metadata"] = panel_meta[pid]
        results.append(base)

    return results

# %%
res = search_images_by_text("Spider-Man fights Mysterio with smoke everywhere", k=5)
for r in res:
    print(r["rank"], r["score"], r["panel_id"], "->", r["image_path"])
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
